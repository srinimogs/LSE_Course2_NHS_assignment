# %% [markdown]
# # Assignment Week 1

# %% [markdown]
# ## My GitHub Repository

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assignment Week 2

# %% [markdown]
# ### Prepare Your Workstation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
#  To import CSV files and check if they load correctly

# %%
ad = pd.read_csv('actual_duration.csv')
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# ...

# %%
ar = pd.read_csv('appointments_regional.csv')
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
nc = pd.read_csv('national_categories.csv')
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %% [markdown]
# ### To sense-check the DataFrames after importing them into Pandas

# %% [markdown]
#  #### to show column names in the data files

# %%
# ad = actual_duration.csv data file
print(ad.columns)
# Out:
# Index(['sub_icb_location_code', 'sub_icb_location_ons_code',
#        'sub_icb_location_name', 'icb_ons_code', 'region_ons_code',
#        'appointment_date', 'actual_duration', 'count_of_appointments'],
#       dtype='object')

# %%
# nc = national_category.csv data file
print(nc.columns)
# Out:
# Index(['appointment_date', 'icb_ons_code', 'sub_icb_location_name',
#        'service_setting', 'context_type', 'national_category',
#        'count_of_appointments', 'appointment_month'],
#       dtype='object')

# %%
# ar = appointments_regional.csv data file
print(ar.columns)
# Out:
# Index(['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type',
#        'appointment_mode', 'time_between_book_and_appointment',
#        'count_of_appointments'],
#       dtype='object')

# %% [markdown]
#  #### to show the data types in the data files

# %%
# ar = appointments_regional.csv data file
ar.dtypes
# Out:
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object

# %%
# nc = national_category.csv data file
nc.dtypes
# Out:
# appointment_date         object
# icb_ons_code             object
# sub_icb_location_name    object
# service_setting          object
# context_type             object
# national_category        object
# count_of_appointments     int64
# appointment_month        object
# dtype: object

# %%
# actual_duration.csv data file
ad.dtypes
# Out:
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object

# %% [markdown]
# #### check for missing values

# %%
ad_na = ad[ad.isna().any(axis=1)]
ad_na.shape
# Out:
# (0, 8)

# %%
ar_na = ar[ar.isna().any(axis=1)]
ar_na.shape
# Out:
# (0, 7)

# %%
nc_na = nc[nc.isna().any(axis=1)]
nc_na.shape
# Out:
# (0, 8)

# %% [markdown]
# #### to find out the number of columns and rows through metadata of file

# %%
# nc = national_category.csv data file
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  object
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 49.9+ MB

# %%
# ad = actual_duration.csv data file
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB

# %%
# ar = appointments_regional.csv data file
ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB

# %% [markdown]
# ### Explore the dataset

# %% [markdown]
# #### Q1 How many locations are there in the data set?

# %% [markdown]
# 1A] Total Number per location in the "actual_duration.csv" data file

# %%
ad['sub_icb_location_name'].value_counts()
# Out:
# NHS Norfolk and Waveney ICB - 26A                       1484
# NHS Kent and Medway ICB - 91Q                           1484
# NHS North West London ICB - W2U3Z                       1484
# NHS Bedfordshire Luton and Milton Keynes ICB - M1J4Y    1484
# NHS Greater Manchester ICB - 14L                        1484
#                                                         ...
# NHS Staffordshire and Stoke-on-Trent ICB - 05D          1051
# NHS South Yorkshire ICB - 03L                           1028
# NHS North East and North Cumbria ICB - 00P              1025
# NHS South Yorkshire ICB - 02P                           1022
# NHS Cheshire and Merseyside ICB - 01F                   1013
# Name: sub_icb_location_name, Length: 106, dtype: int64

# %% [markdown]
# 1B] total number of locations in the "actual_duration" data file.

# %%
ad_loc = ad['sub_icb_location_name'].value_counts()
print("The Total Number of Locations are: ", ad_loc.sum())
# Out:
# The Total Number of Locations are:  137793

# %% [markdown]
# 2A] total number per locations in the "national_categories" data file.

# %%
nc['sub_icb_location_name'].value_counts()
# Out:
# NHS North West London ICB - W2U3Z              13007
# NHS Kent and Medway ICB - 91Q                  12637
# NHS Devon ICB - 15N                            12526
# NHS Hampshire and Isle Of Wight ICB - D9Y0V    12171
# NHS North East London ICB - A3A8R              11837
#                                                ...
# NHS North East and North Cumbria ICB - 00N      4210
# NHS Lancashire and South Cumbria ICB - 02G      4169
# NHS Cheshire and Merseyside ICB - 01V           3496
# NHS Cheshire and Merseyside ICB - 01T           3242
# NHS Greater Manchester ICB - 00V                2170
# Name: sub_icb_location_name, Length: 106, dtype: int64

# %% [markdown]
# 2B] total number of locations in the "national_categories" data file.

# %%
nc_loc = nc['sub_icb_location_name'].value_counts()
print("The Total Number of Locations is: ", nc_loc.sum())
# Out:
# The Total Number of Locations is:  817394

# %% [markdown]
# #### Q2 What are the five locations with the highest number of records?

# %%
n = 5
ad['sub_icb_location_name'].value_counts()[:5].index.tolist()
# Out:
# ['NHS Norfolk and Waveney ICB - 26A',
#  'NHS Kent and Medway ICB - 91Q',
#  'NHS North West London ICB - W2U3Z',
#  'NHS Bedfordshire Luton and Milton Keynes ICB - M1J4Y',
#  'NHS Greater Manchester ICB - 14L']

# %% [markdown]
# #### Q3 How many service settings, context types, national categories, and appointment statuses are there?

# %% [markdown]
# 1] The types and number of status in the dataset "appointments_regional"

# %%
# where DNA = Did Not Attend, Unknown = not recorded or data missing
ar['appointment_status'].value_counts()
# Out:
# Attended    232137
# Unknown     201324
# DNA         163360
# Name: appointment_status, dtype: int64

# %%
# number of appointment statuses
ar_loc = ar['appointment_status'].value_counts()
print("The Total Number of appointment statuses are: ", ar_loc.sum())
# Out:
# The Total Number of appointment statuses are:  596821

# %% [markdown]
# 2] The types and total number per setting in the dataset "national_category"

# %%
# to show number of times a service setting occurs in the file
nc['service_setting'].value_counts()
# Out:
# General Practice             359274
# Primary Care Network         183790
# Other                        138789
# Extended Access Provision    108122
# Unmapped                      27419
# Name: service_setting, dtype: int64

# %%
# the total number of service settings in the data file
nc_loc = nc['service_setting'].value_counts()
print("The Total Number of service status in the file are: ", nc_loc.sum())
# Out:
# The Total Number of service status in the file are:  817394

# %% [markdown]
# 3] The types of context of treatment and the corresponding numbers

# %%
 # nc = national_category.csv data file
# the number of ambiguous recordings are high
nc['context_type'].value_counts()
# Out:
# Care Related Encounter    700481
# Inconsistent Mapping       89494
# Unmapped                   27419
# Name: context_type, dtype: int64

# %%
# the total number of service settings in the data file
nc_loc = nc['context_type'].value_counts()
print("The Total Number of context types in the file are: ", nc_loc.sum())
# Out:
# The Total Number of context types in the file are:  817394

# %% [markdown]
# 4] The types of treatment and their total numbers

# %%
# nc = national_category.csv data file
nc['national_category'].value_counts()
# Out:
# Inconsistent Mapping                                                   89494
# General Consultation Routine                                           89329
# General Consultation Acute                                             84874
# Planned Clinics                                                        76429
# Clinical Triage                                                        74539
# Planned Clinical Procedure                                             59631
# Structured Medication Review                                           44467
# Service provided by organisation external to the practice              43095
# Home Visit                                                             41850
# Unplanned Clinical Activity                                            40415
# Patient contact during Care Home Round                                 28795
# Unmapped                                                               27419
# ...

# %%
# the total number of national categories in the data file
nc_loc = nc['national_category'].value_counts()
print("The Total Number of context types in the file are: ", nc_loc.sum())
# Out:
# The Total Number of context types in the file are:  817394

# %% [markdown]
# # Assignment Week 3

# %% [markdown]
# #### Q1 Between what dates were appointments scheduled ?

# %% [markdown]
# #### A1: The appointments were between 31st December, 2021 to 1st January, 2022

# %%
nc['appointment_date'] = pd.to_datetime(nc['appointment_date'])

# %%
nc['appointment_date'] = nc['appointment_date'].dt.strftime('%d-%m-%y')

# %%
nc1 = nc['appointment_date'].min()

# %%
print("The last date of Appointment was: ", nc1)
# Out:
# The last date of Appointment was:  01-01-22

# %%
nc1 = nc['appointment_date'].max()

# %%
print("The first date of Appointment was: ", nc1)
# Out:
# The first date of Appointment was:  31-12-21

# %% [markdown]
# #### Q2 Which service setting reported the most appointments in North West London from 1 January to 1 June 2022?

# %%
# created a subset of the original dataset for ease of analysis and to get relevant information only
nc_subset = nc[['appointment_date', 'sub_icb_location_name', 'service_setting', 'count_of_appointments']]

# %%
# This output gives the number of appointments pre month and per service setting 
# This output is only for NHS North West London ICB - W2U3Z
nc_subset.loc[(nc['appointment_date']>='01-01-22') & (nc_subset['appointment_date']<'01-06-22')
             & (nc_subset['sub_icb_location_name'] == 'NHS North West London ICB - W2U3Z')].value_counts()
# Out:
# appointment_date  sub_icb_location_name              service_setting       count_of_appointments
# 2021-08-31        NHS North West London ICB - W2U3Z  Other                 1                        3
# 2021-12-17        NHS North West London ICB - W2U3Z  Primary Care Network  1                        3
# 2022-01-03        NHS North West London ICB - W2U3Z  Other                 1                        3
# 2021-09-21        NHS North West London ICB - W2U3Z  Other                 4                        3
# 2021-12-22        NHS North West London ICB - W2U3Z  Other                 1                        3
#                                                                                                    ..
# 2021-08-25        NHS North West London ICB - W2U3Z  Primary Care Network  14                       1
#                                                                            4                        1
# ...

# %% [markdown]
# #### Q3 Which month had the highest number of appointments?

# %%
nc_subset['appointment_date'] = pd.to_datetime(nc_subset['appointment_date'])
# Out:
# C:\Users\srini\AppData\Local\Temp\ipykernel_14892\3654993688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nc_subset['appointment_date'] = pd.to_datetime(nc_subset['appointment_date'])

# %%
ac2 = nc_subset.sort_values(['count_of_appointments'], ascending=False).groupby([nc_subset['appointment_date'].dt.year, 
                                nc_subset['appointment_date'].dt.month]).head()
print(ac2)
# Out:
#        appointment_date              sub_icb_location_name   service_setting  \
# 732144       2022-09-05  NHS North East London ICB - A3A8R  General Practice
# 732705       2022-05-23  NHS North East London ICB - A3A8R  General Practice
# 724735       2021-11-10  NHS North East London ICB - A3A8R  General Practice
# 724978       2021-10-18  NHS North East London ICB - A3A8R  General Practice
# 732446       2022-05-16  NHS North East London ICB - A3A8R  General Practice
# ...                 ...                                ...               ...
# 797995       2021-03-11  NHS North West London ICB - W2U3Z  General Practice
# 619806       2022-12-05    NHS South East London ICB - 72Q  General Practice
# 613813       2021-03-11    NHS South East London ICB - 72Q  General Practice
# 726648       2021-02-12  NHS North East London ICB - A3A8R  General Practice
# 799212       2021-03-12  NHS North West London ICB - W2U3Z  General Practice
#
#         count_of_appointments
# ...

# %% [markdown]
# #### Q4 What was the total number of records per month?

# %%
# This listing gives a glimpse of which months in the year had the highest number of records
# records are all the rows where information was recorded in a correct manner
nc['appointment_month'].value_counts(ascending=True)
# Out:
# 2021-08    69999
# 2022-04    70012
# 2022-02    71769
# 2022-01    71896
# 2021-12    72651
# 2021-10    74078
# 2022-06    74168
# 2021-09    74922
# 2022-05    77425
# 2021-11    77652
# 2022-03    82822
# Name: appointment_month, dtype: int64

# %% [markdown]
# # Assignment Week 4

# %% [markdown]
# ## Prepare your workstation

# %%
# import all the libraries needed 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# %%
# Set the plot style as white.
sns.set_style('white')

# %% [markdown]
# ## Objective 1

# %% [markdown]
# #### Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories

# %%
# change data type of "appointment_month" for better visualisation
nc_ss1 = nc_ss.loc[ : , 'appointment_month'].convert_dtypes()

# %%
# Aggregate on monthly level and determine the sum of records per month
# Execute the below code for columns 'service setting'
nc_ss = nc.groupby(['appointment_month', 'service_setting']).sum().reset_index()

# %% [markdown]
# #### the output of code for service_Setting column
# ![image.png](attachment:image.png)

# %%
# Execute the below code for columns 'context types'
nc_ss = nc.groupby(['appointment_month', 'context_type']).sum().reset_index()

# %% [markdown]
# #### the output of code for context setting
# ![image.png](attachment:image.png)

# %%
# Execute the below code for columns 'national category'
nc_ss = nc.groupby(['appointment_month', 'national_category']).sum().reset_index()

# %% [markdown]
# #### the output of code for national category
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Create Lineplots for "Service Setting", "Context Type", "National Category"

# %% [markdown]
# #### Lineplot for "Service Setting"
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Lineplot for "Context Type"
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Lineplot for "National Category"
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Objective 2

# %% [markdown]
# #### Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (August 2021), autumn (October 2021), winter (January 2022), and spring (April 2022

# %% [markdown]
# **Summer (August 2021):**

# %%
# create a dataset to be used for analysis of the seasons
nc_ss = nc.groupby(['appointment_month', 'appointment_date', 'service_setting']).sum().reset_index()

# %% [markdown]
# #### The output for the above dataset
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Create a Lineplot
# sns.lineplot(x='service_setting', y='count_of_appointments', hue='appointment_month'=='2021-08', data=nc_ss, ci=None)
# ![image.png](attachment:image.png)

# %% [markdown]
# **Autumn (October 2021):**

# %% [markdown]
# #### Create a Lineplot
# sns.lineplot(x='service_setting', y='count_of_appointments', hue='appointment_month'=='2021-10', data=nc_ss, ci=None)
# ![image.png](attachment:image.png)

# %% [markdown]
# **Winter (January 2022):**

# %% [markdown]
# #### Create a Lineplot
# sns.lineplot(x='service_setting', y='count_of_appointments', hue='appointment_month'=='2022-01', data=nc_ss, ci=None)
# ![image.png](attachment:image.png)

# %% [markdown]
# **Spring (April 2022):**

# %% [markdown]
# #### Create a Lineplot
# sns.lineplot(x='service_setting', y='count_of_appointments', hue='appointment_month'=='2022-04', data=nc_ss, ci=None)
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Create a Lineplot for all Seasons
# sns.lineplot(x='service_setting', y='count_of_appointments', hue='appointment_month', data=nc_ss, ci=None)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assignment Week 5

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests 
from bs4 import BeautifulSoup

# %%
# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200

# %% [markdown]
# ### Q2 Prepare and explore the data

# %%
tweets = pd.read_csv('tweets.csv')

# %%
tweets.head()
# Out:
#               tweet_id  \
# 0  1567629223795527681
# 1  1567582846612553728
# 2  1567582787070304256
# 3  1567582767625428992
# 4  1567582720460570625
#
#                                                                                                                                                                                            tweet_full_text  \
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                              RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                           RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# ...

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1174 non-null   int64
#  1   tweet_full_text          1174 non-null   object
#  2   tweet_entities           1174 non-null   object
#  3   tweet_entities_hashtags  1007 non-null   object
#  4   tweet_metadata           1174 non-null   object
#  5   tweet_retweet_count      1174 non-null   int64
#  6   tweet_favorite_count     1174 non-null   int64
#  7   tweet_favorited          1174 non-null   bool
#  8   tweet_retweeted          1174 non-null   bool
#  9   tweet_lang               1174 non-null   object
# dtypes: bool(2), int64(3), object(5)
# memory usage: 75.8+ KB

# %%
tweets.describe()
# Out:
#            tweet_id  tweet_retweet_count  tweet_favorite_count
# count  1.174000e+03          1174.000000            1174.00000
# mean   1.567612e+18             8.629472               0.37138
# std    2.427553e+13            29.784675               2.04470
# min    1.567574e+18             0.000000               0.00000
# 25%    1.567590e+18             0.000000               0.00000
# 50%    1.567611e+18             1.000000               0.00000
# 75%    1.567633e+18             3.000000               0.00000
# max    1.567655e+18           303.000000              42.00000

# %%
# to have a look at the retweets in the database
tweets['tweet_retweet_count'].value_counts()
# Out:
# 0      526
# 1      215
# 2      114
# 3       70
# 5       35
# 4       27
# 7       18
# 12      16
# 8       15
# 73      14
# 9       13
# 6       12
# 208     12
# 35      10
# 37       6
# 11       6
# 10       5
# 53       5
# 44       4
# 150      4
# 63       4
# 76       3
# 85       3
# 41       3
# 62       3
# 207      3
# 68       3
# 78       2
# 23       2
# 24       2
# 72       2
# 16       2
# 13       1
# 49       1
# 48       1
# 15       1
# 107      1
# 14       1
# 79       1
# 20       1
# 39       1
# 19       1
# 303      1
# 57       1
# 40       1
# 54       1
# 169      1
# Name: tweet_retweet_count, dtype: int64

# %% [markdown]
# As is evident from above the table gives no imformation about which tweets are associated with the numbers and hence no inference can be drawn form it as they are just a series of meaningless numbers.

# %%
# to have a look at the favourite tweet count in the database
tweets['tweet_favorite_count'].value_counts()
# Out:
# 0     1027
# 1       91
# 2       16
# 3       13
# 4        7
# 5        5
# 6        2
# 17       1
# 12       1
# 10       1
# 8        1
# 13       1
# 11       1
# 7        1
# 20       1
# 28       1
# 14       1
# 18       1
# 9        1
# 42       1
# Name: tweet_favorite_count, dtype: int64

# %% [markdown]
# the above table illustrates nothing as it is just a table of numbers but as is not associated with any other information such which are the tweets in question, this table and its onctents can be discarded.

# %%
tweets_text = tweets['tweet_full_text']

# %%
tweets_text.head()
# Out:
# 0    As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                             RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# 3                                                               RT @modrnhealthcr: 🚨#NEW:🚨 Insurance companies are figuring out the best ways to collect information about members’ race and ethnicity data…
# ...

# %% [markdown]
# ### Q3 Review the hashtags(#)

# %% [markdown]
# #### Create a new dataframe form the information in the column "tweet_full_text"

# %%
tags = []

for y in [x.split(' ') for x in tweets['tweet_full_text'].values]:
    for z in y:
        if '#' in z:
            # Change to lowercase.
            tags.append(z.lower())

# %%
tags
# Out:
# ['#healthcare',
#  '#premisehealth',
#  '#hiring',
#  '#healthcare',
#  '🚨#new:🚨',
#  'look!\n\n#blogs',
#  '#digitaltransformation',
#  '#cybersecurity',
#  '#accounting',
#  '#finance',
#  '#healthcare',
#  'https://t.co/jrgqeqdme4\n.\n#firstcoastcna',
#  '#cnaexam',
#  '#cnaexampreparation',
#  '#jacksonville',
#  '#cnatraining',
#  '#nurse',
#  '#nursing',
#  '#nurselife',
#  '#nursepractitioner',
#  '#nurseproblems',
#  '#nursingschool',
#  '#healthcare',
#  '🚨#new:🚨',
#  '#disparities.',
#  '@karahartnett\n#healthcare',
#  '#alert',
#  '#insurance',
#  '#data\nhttps://t.co/h9hlamr7p9',
#  '#healthcare',
#  '#healthcare',
#  '❤️\n\n#healthcare',
#  '#healthcare',
#  '#hcldr',
#  '#premisehealth',
#  '#hiring',
#  '#premisehealth',
#  '#hiring',
#  '#healthcare',
#  '#qualitypatientcare',
#  '#jobs',
#  '#job',
#  '#ascp2022',
#  '#ascp100.',
#  '#healthcare',
#  '#healthsecretary',
#  '#healthcare',
#  '#ai,',
#  '#sdoh,',
#  '#healthcare',
# ...

# %% [markdown]
# #### create a series and display the first 30 records with '#' symbol

# %%
tags = pd.Series(tags)
tags
# Out:
# 0              #healthcare
# 1           #premisehealth
# 2                  #hiring
# 3              #healthcare
# 4                  🚨#new:🚨
#                ...
# 4328    #mediqueststaffing
# 4329             #hospital
# 4330                #shift
# 4331       (#newportbeach)
# 4332                  #job
# Length: 4333, dtype: object

# %%
tags = tags.value_counts().head(30)

# %%
tags
# Out:
# #healthcare                    716
# #health                         80
# #medicine                       41
# #ai                             40
# #job                            38
# #medical                        35
# #strategy                       30
# #pharmaceutical                 28
# #digitalhealth                  25
# #pharma                         25
# #marketing                      25
# #medtwitter                     24
# #biotech                        24
# #competitiveintelligence        24
# #meded                          23
# #vaccine                        18
# #hiring                         18
# #news                           17
# #machinelearning                17
# #technology                     17
# #coronavirus                    16
# #womeninmedicine                16
# #covid                          16
# #competitivemarketing           16
# #wellness                       15
# #healthtech                     15
# #doctorofveterinarymedicine     14
# ...

# %% [markdown]
# #### create a dataframe with the series

# %%
data = pd.DataFrame(tags).reset_index()
data
# Out:
#                           index    0
# 0                   #healthcare  716
# 1                       #health   80
# 2                     #medicine   41
# 3                           #ai   40
# 4                          #job   38
# 5                      #medical   35
# 6                     #strategy   30
# 7               #pharmaceutical   28
# 8                #digitalhealth   25
# 9                       #pharma   25
# 10                   #marketing   25
# 11                  #medtwitter   24
# 12                     #biotech   24
# 13     #competitiveintelligence   24
# 14                       #meded   23
# 15                     #vaccine   18
# 16                      #hiring   18
# 17                        #news   17
# 18             #machinelearning   17
# 19                  #technology   17
# 20                 #coronavirus   16
# 21             #womeninmedicine   16
# 22                       #covid   16
# 23        #competitivemarketing   16
# ...

# %% [markdown]
# #### rename the columns

# %%
data.columns = ['Word', 'Count']
data.head()
# Out:
#           Word  Count
# 0  #healthcare    716
# 1      #health     80
# 2    #medicine     41
# 3          #ai     40
# 4         #job     38

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Word    30 non-null     object
#  1   Count   30 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 608.0+ bytes

# %%
data.describe()
# Out:
#             Count
# count   30.000000
# mean    47.166667
# std    127.015362
# min     14.000000
# 25%     16.000000
# 50%     20.500000
# 75%     27.250000
# max    716.000000

# %%
data['Count'] = data['Count'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Word    30 non-null     object
#  1   Count   30 non-null     int32
# dtypes: int32(1), object(1)
# memory usage: 488.0+ bytes

# %% [markdown]
# ### Q4 top trending hashtags with a visualisation

# %% [markdown]
# ### create a barplot with the data

# %% [markdown]
# ##### as can be seen from the below plot, although it is easy to recognie that "#healthcare" is th emost popular hashtag, it is because of the height of the bar in theplot, but the others are not that easily distinguishable and another way I can to improve would be to split the data in to smaller parts and then plot different barplots and then compare the results. This is because of the large number of different hashtags which clutter up the plt.

# %%
sns.barplot(x='Word', y='Count', estimator=sum, data=data)
# Out:
# <AxesSubplot:xlabel='Word', ylabel='Count'>

# %% [markdown]
# ### Remove the Outliers and create the barplot again

# %%
# The columns you want to search for outliers in.
cols = ['Count'] 

# Calculate quantiles and IQR.
# Same as np.percentile but maps (0,1) and not (0,100).
Q1 = data[cols].quantile(0.25) 
Q3 = data[cols].quantile(0.75)
IQR = Q3 - Q1
IQR

# Return a Boolean array of the rows with (any) non-outlier column values.
condition = ~((data[cols] < (Q1 - 1.5 * IQR)) | (data[cols] > (Q3 + 1.5 * IQR))).any(axis=1)

# Filter our DataFrame based on condition.
data_non_outlier = data[condition]
data_non_outlier.shape
# Out:
# (28, 2)

# %%
sns.barplot(x='Word', y=data_non_outlier['Count'], data=data)
# Out:
# <AxesSubplot:xlabel='Word', ylabel='Count'>

# %% [markdown]
# ### Q5 Reflection on the Article "How to Use Twitter for Business" by Saige Driver

# %% [markdown]
# Twitter today is one of the best-known tools for communication in the wide world and its ability to reach a global audience is unprecedented. The ability to reach all corners of the globe with your message or campaign or information enables many companies and organisations across the world to use it extensively to propagate their marketing campaigns and sales promotions and other messages to a vast audience at the same time and same instant thus making it an invaluable tool.  It’s also a great tool to organise any kind of feedback to customers regarding their views on the company itself to the services that it offers and other aspects of the company. If NHS is taken into consideration here, then the team at NHS have a tool at their disposal to answer any queries that a patient might post on twitter when that particular patient did not get the right answers from elsewhere.
#
# The NHS team can use twitter to send information regarding campaigns such as Mental Health, recent COVID related messages and information, Dementia and many other types of ailments about which not many people know about or have scant information. Individual NHS trusts can also leverage the power of twitter by sending information about any new developments in the trust such as new treatments being offered or a new appointment booking system. NHS can use the facility of Direct Messages that twitter offers to communicate with the patient about any problems they are facing and are unable to let their General Practitioners know. Or they can answer grievances any use of NHS might have who has chosen to air their views publicly. This can help stop the negative opinion developing.
#
# Tweets in my opinion add value to NHS services. Most of the times NHS relies on sending information through post or text messages or emails. These can be hit-or-miss and other than text messages which are for specific individual only, the other mediums are incapable of addressing the larger audience together and effectively. Tweets come in handy as they reach the intended audience immediately and are also cost effective. Reading a few words is easy for people rather than reading a couple of pages full of information that has come through the door. Direct Messgaes facility offered by twitter can be used by NHS for after-care services and follow ups. NHS has finally woken upto the advantage of using twitter to communicate directly with patients, provide links to websites which offer information about any doseases and control.
#
# for further information on how NHS uses twitter now can be had from this link below:
#
# https://www.theguardian.com/healthcare-network/2011/feb/16/nhs-twitter-use-tweets-communication-healthcare#:~:text=%22Twitter%20is%20an%20additional%20way,not%20get%20in%20touch%20directly.

# %% [markdown]
# # Assignment Week 6

# %% [markdown]
# ### Prepare the Workstation

# %%
ar.head(5)
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %% [markdown]
# ##### Maximum Dates

# %%
ar1 = ar['appointment_month'].max()
print('The Maximum Date is:', ar1 )
# Out:
# The Maximum Date is: 2022-06

# %% [markdown]
# ##### Minimum Date

# %%
ar1 = ar['appointment_month'].min()
print('The minimum Date is:', ar1 )
# Out:
# The minimum Date is: 2020-01

# %%
ar1 = ar[ar['appointment_month'] > '2021-08']
ar1.head(5)
# Out:
#      icb_ons_code appointment_month appointment_status hcp_type  \
# 3850    E54000034           2021-09           Attended       GP
# 3851    E54000034           2021-09           Attended       GP
# 3852    E54000034           2021-09           Attended       GP
# 3853    E54000034           2021-09           Attended       GP
# 3854    E54000034           2021-09           Attended       GP
#
#      appointment_mode time_between_book_and_appointment  count_of_appointments
# 3850     Face-to-Face                             1 Day                   8288
# 3851     Face-to-Face                    15  to 21 Days                   3827
# 3852     Face-to-Face                       2 to 7 Days                  13466
# 3853     Face-to-Face                    22  to 28 Days                   1300
# 3854     Face-to-Face                     8  to 14 Days                   6825

# %% [markdown]
# #### Q1 Should the NHS start looking at increasing staff levels?

# %% [markdown]
# ##### Q1 - 1] Create a new data set:

# %%
ar_agg = ar1.groupby(['appointment_month', 'hcp_type', 'appointment_status', 'appointment_mode', \
                     'time_between_book_and_appointment']).sum().reset_index()
ar_agg.head()
# Out:
#   appointment_month hcp_type appointment_status appointment_mode  \
# 0           2021-09       GP           Attended     Face-to-Face
# 1           2021-09       GP           Attended     Face-to-Face
# 2           2021-09       GP           Attended     Face-to-Face
# 3           2021-09       GP           Attended     Face-to-Face
# 4           2021-09       GP           Attended     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                 672515
# 1                    15  to 21 Days                 277425
# 2                       2 to 7 Days                1222198
# 3                    22  to 28 Days                 158988
# 4                     8  to 14 Days                 538724

# %% [markdown]
# #### Q1 - 2] Determine average utilisation of services:

# %%
ar_df = ar_agg.groupby(['appointment_month', 'count_of_appointments']).sum().reset_index()
ar_df.head()
# Out:
#   appointment_month  count_of_appointments  \
# 0           2021-09                      1
# 1           2021-09                      2
# 2           2021-09                      4
# 3           2021-09                      5
# 4           2021-09                      6
#
#                                     hcp_type             appointment_status  \
# 0        UnknownUnknownUnknownUnknownUnknown  AttendedAttendedDNADNAUnknown
# 1  Other Practice staffUnknownUnknownUnknown   UnknownUnknownUnknownUnknown
# 2                                         GP                        Unknown
# 3                                         GP                        Unknown
# 4                             UnknownUnknown                    AttendedDNA
#
#                                     appointment_mode  \
# 0  Video/OnlineVideo/OnlineHome VisitUnknownVideo...
# 1        UnknownVideo/OnlineVideo/OnlineVideo/Online
# 2                                       Video/Online
# ...

# %%
ar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3178 entries, 0 to 3177
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   appointment_month                  3178 non-null   object
#  1   count_of_appointments              3178 non-null   int64
#  2   hcp_type                           3178 non-null   object
#  3   appointment_status                 3178 non-null   object
#  4   appointment_mode                   3178 non-null   object
#  5   time_between_book_and_appointment  3178 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 149.1+ KB

# %%
ar_df.columns
# Out:
# Index(['appointment_month', 'count_of_appointments', 'hcp_type',
#        'appointment_status', 'appointment_mode',
#        'time_between_book_and_appointment'],
#       dtype='object')

# %%
ar_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3414 entries, 0 to 3413
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   appointment_month                  3414 non-null   object
#  1   hcp_type                           3414 non-null   object
#  2   appointment_status                 3414 non-null   object
#  3   appointment_mode                   3414 non-null   object
#  4   time_between_book_and_appointment  3414 non-null   object
#  5   count_of_appointments              3414 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 160.2+ KB

# %% [raw]
# ar_agg['appointment_month'] = ar_agg['appointment_month'].convert_dtypes()

# %%
ar_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3414 entries, 0 to 3413
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   appointment_month                  3414 non-null   object
#  1   hcp_type                           3414 non-null   object
#  2   appointment_status                 3414 non-null   object
#  3   appointment_mode                   3414 non-null   object
#  4   time_between_book_and_appointment  3414 non-null   object
#  5   count_of_appointments              3414 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 160.2+ KB

# %%
ar_df['appointment_month'] = ar_df['appointment_month'].convert_dtypes()

# %%
ar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3178 entries, 0 to 3177
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   appointment_month                  3178 non-null   string
#  1   count_of_appointments              3178 non-null   int64
#  2   hcp_type                           3178 non-null   object
#  3   appointment_status                 3178 non-null   object
#  4   appointment_mode                   3178 non-null   object
#  5   time_between_book_and_appointment  3178 non-null   object
# dtypes: int64(1), object(4), string(1)
# memory usage: 149.1+ KB

# %%
ar_df['utilisation'] = ar_df['appointment_month'].count() / 30

# %%
ar_df.head()
# Out:
#   appointment_month  count_of_appointments  \
# 0           2021-09                      1
# 1           2021-09                      2
# 2           2021-09                      4
# 3           2021-09                      5
# 4           2021-09                      6
#
#                                     hcp_type             appointment_status  \
# 0        UnknownUnknownUnknownUnknownUnknown  AttendedAttendedDNADNAUnknown
# 1  Other Practice staffUnknownUnknownUnknown   UnknownUnknownUnknownUnknown
# 2                                         GP                        Unknown
# 3                                         GP                        Unknown
# 4                             UnknownUnknown                    AttendedDNA
#
#                                     appointment_mode  \
# 0  Video/OnlineVideo/OnlineHome VisitUnknownVideo...
# 1        UnknownVideo/OnlineVideo/OnlineVideo/Online
# 2                                       Video/Online
# ...

# %% [markdown]
# ### Lineplots with Seaborn

# %% [markdown]
# #### Q3 Create lineplots for number of monthly visits & monthly capacity utilisation

# %%
ar_plot = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='time_between_book_and_appointment', estimator=sum, data=ar_agg)
ar_plot.set(xlabel='Appointment Month', ylabel='Number of Appointments', title='Number of Monthly Visits')
# Out:
# [Text(0.5, 0, 'Appointment Month'),
#  Text(0, 0.5, 'Number of Appointments'),
#  Text(0.5, 1.0, 'Number of Monthly Visits')]

# %%
ar_plot1 = sns.lineplot(x='appointment_month', y='utilisation', estimator=sum, data=ar_df)
ar_plot1.set(xlabel='Appointment Month', ylabel='Utilisation of Resources', title='Monthly Capacity Utilisation')
# Out:
# [Text(0.5, 0, 'Appointment Month'),
#  Text(0, 0.5, 'Utilisation of Resources'),
#  Text(0.5, 1.0, 'Monthly Capacity Utilisation')]

# %% [markdown]
# # Assignment Week 5

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200

# %%
tweets = pd.read_csv('tweets.csv')
tweets.head(1)
# Out:
#               tweet_id  \
# 0  1567629223795527681
#
#                                                                                                                                                                                            tweet_full_text  \
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
#
#                                                                                                                                                                                             tweet_entities  \
# 0  {'hashtags': [{'text': 'Healthcare', 'indices': [253, 264]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/yw0cstfmSI', 'expanded_url': 'https://bit.ly/3BiSKbs', 'display_url...
#
#   tweet_entities_hashtags  \
# 0             #Healthcare
#
# ...

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1174 non-null   int64
#  1   tweet_full_text          1174 non-null   object
#  2   tweet_entities           1174 non-null   object
#  3   tweet_entities_hashtags  1007 non-null   object
#  4   tweet_metadata           1174 non-null   object
#  5   tweet_retweet_count      1174 non-null   int64
#  6   tweet_favorite_count     1174 non-null   int64
#  7   tweet_favorited          1174 non-null   bool
#  8   tweet_retweeted          1174 non-null   bool
#  9   tweet_lang               1174 non-null   object
# dtypes: bool(2), int64(3), object(5)
# memory usage: 75.8+ KB

# %%
tweets.describe()
# Out:
#            tweet_id  tweet_retweet_count  tweet_favorite_count
# count  1.174000e+03          1174.000000            1174.00000
# mean   1.567612e+18             8.629472               0.37138
# std    2.427553e+13            29.784675               2.04470
# min    1.567574e+18             0.000000               0.00000
# 25%    1.567590e+18             0.000000               0.00000
# 50%    1.567611e+18             1.000000               0.00000
# 75%    1.567633e+18             3.000000               0.00000
# max    1.567655e+18           303.000000              42.00000

# %%
tweets['tweet_retweet_count'].value_counts()
# Out:
# 0      526
# 1      215
# 2      114
# 3       70
# 5       35
# 4       27
# 7       18
# 12      16
# 8       15
# 73      14
# 9       13
# 6       12
# 208     12
# 35      10
# 37       6
# 11       6
# 10       5
# 53       5
# 44       4
# 150      4
# 63       4
# 76       3
# 85       3
# 41       3
# 62       3
# 207      3
# 68       3
# 78       2
# 23       2
# 24       2
# 72       2
# 16       2
# 13       1
# 49       1
# 48       1
# 15       1
# 107      1
# 14       1
# 79       1
# 20       1
# 39       1
# 19       1
# 303      1
# 57       1
# 40       1
# 54       1
# 169      1
# Name: tweet_retweet_count, dtype: int64

# %% [markdown]
# As is evident from above the table gives no imformation about which tweets are associated with the numbers and hence no inference can be drawn form it as they are just a series of meaningless numbers.

# %%
# to have a look at the favourite tweet count in the database
tweets['tweet_favorite_count'].value_counts()
# Out:
# 0     1027
# 1       91
# 2       16
# 3       13
# 4        7
# 5        5
# 6        2
# 17       1
# 12       1
# 10       1
# 8        1
# 13       1
# 11       1
# 7        1
# 20       1
# 28       1
# 14       1
# 18       1
# 9        1
# 42       1
# Name: tweet_favorite_count, dtype: int64

# %% [markdown]
# the above table illustrates nothing as it is just a table of numbers but as is not associated with any other information such which are the tweets in question, this table and its onctents can be discarded.

# %%
tweets_text = tweets['tweet_full_text']
tweets_text.head()
# Out:
# 0    As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                             RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# 3                                                               RT @modrnhealthcr: 🚨#NEW:🚨 Insurance companies are figuring out the best ways to collect information about members’ race and ethnicity data…
# ...

# %% [markdown]
# ### Q3 Review the hashtags(#)

# %% [markdown]
# #### Create a new dataframe form the information in the column "tweet_full_text"

# %%
tags = []

for y in [x.split(' ') for x in tweets['tweet_full_text'].values]:
    for z in y:
        if '#' in z:
            # Change to lowercase.
            tags.append(z.lower())

# %%
tags
# Out:
# ['#healthcare',
#  '#premisehealth',
#  '#hiring',
#  '#healthcare',
#  '🚨#new:🚨',
#  'look!\n\n#blogs',
#  '#digitaltransformation',
#  '#cybersecurity',
#  '#accounting',
#  '#finance',
#  '#healthcare',
#  'https://t.co/jrgqeqdme4\n.\n#firstcoastcna',
#  '#cnaexam',
#  '#cnaexampreparation',
#  '#jacksonville',
#  '#cnatraining',
#  '#nurse',
#  '#nursing',
#  '#nurselife',
#  '#nursepractitioner',
#  '#nurseproblems',
#  '#nursingschool',
#  '#healthcare',
#  '🚨#new:🚨',
#  '#disparities.',
#  '@karahartnett\n#healthcare',
#  '#alert',
#  '#insurance',
#  '#data\nhttps://t.co/h9hlamr7p9',
#  '#healthcare',
#  '#healthcare',
#  '❤️\n\n#healthcare',
#  '#healthcare',
#  '#hcldr',
#  '#premisehealth',
#  '#hiring',
#  '#premisehealth',
#  '#hiring',
#  '#healthcare',
#  '#qualitypatientcare',
#  '#jobs',
#  '#job',
#  '#ascp2022',
#  '#ascp100.',
#  '#healthcare',
#  '#healthsecretary',
#  '#healthcare',
#  '#ai,',
#  '#sdoh,',
#  '#healthcare',
# ...

# %% [markdown]
# #### create a series and display the first 30 records with '#' symbol

# %%
tags = pd.Series(tags)
tags
# Out:
# 0              #healthcare
# 1           #premisehealth
# 2                  #hiring
# 3              #healthcare
# 4                  🚨#new:🚨
#                ...
# 4328    #mediqueststaffing
# 4329             #hospital
# 4330                #shift
# 4331       (#newportbeach)
# 4332                  #job
# Length: 4333, dtype: object

# %%
tags = tags.value_counts().head(30)

# %%
tags
# Out:
# #healthcare                    716
# #health                         80
# #medicine                       41
# #ai                             40
# #job                            38
# #medical                        35
# #strategy                       30
# #pharmaceutical                 28
# #digitalhealth                  25
# #pharma                         25
# #marketing                      25
# #medtwitter                     24
# #biotech                        24
# #competitiveintelligence        24
# #meded                          23
# #vaccine                        18
# #hiring                         18
# #news                           17
# #machinelearning                17
# #technology                     17
# #coronavirus                    16
# #womeninmedicine                16
# #covid                          16
# #competitivemarketing           16
# #wellness                       15
# #healthtech                     15
# #doctorofveterinarymedicine     14
# ...

# %% [markdown]
# #### create a dataframe with the series

# %%
data = pd.DataFrame(tags).reset_index()
data.head(3)
# Out:
#          index    0
# 0  #healthcare  716
# 1      #health   80
# 2    #medicine   41

# %%
data.columns = ['Word', 'Count']
data.head()
# Out:
#           Word  Count
# 0  #healthcare    716
# 1      #health     80
# 2    #medicine     41
# 3          #ai     40
# 4         #job     38

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Word    30 non-null     object
#  1   Count   30 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 608.0+ bytes

# %%
data.describe()
# Out:
#             Count
# count   30.000000
# mean    47.166667
# std    127.015362
# min     14.000000
# 25%     16.000000
# 50%     20.500000
# 75%     27.250000
# max    716.000000

# %%
data['Count'] = data['Count'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Word    30 non-null     object
#  1   Count   30 non-null     int32
# dtypes: int32(1), object(1)
# memory usage: 488.0+ bytes

# %% [markdown]
# ### Q4 top trending hashtags with a visualisation

# %% [markdown]
# ### create a barplot with the data

# %% [markdown]
# ##### as can be seen from the below plot, although it is easy to recognie that "#healthcare" is th emost popular hashtag, it is because of the height of the bar in theplot, but the others are not that easily distinguishable and another way I can to improve would be to split the data in to smaller parts and then plot different barplots and then compare the results. This is because of the large number of different hashtags which clutter up the plt.

# %%
data_count = data[data['Count'] > 10]
data_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Word    30 non-null     object
#  1   Count   30 non-null     int32
# dtypes: int32(1), object(1)
# memory usage: 600.0+ bytes

# %%
sns.barplot(x='Word', y='Count', estimator=sum, data=data_count)
# Out:
# <AxesSubplot:xlabel='Word', ylabel='Count'>

# %% [markdown]
# ### Q5 Reflection on the Article "How to Use Twitter for Business" by Saige Driver

# %% [markdown]
# Twitter today is one of the best-known tools for communication in the wide world and its ability to reach a global audience is unprecedented. The ability to reach all corners of the globe with your message or campaign or information enables many companies and organisations across the world to use it extensively to propagate their marketing campaigns and sales promotions and other messages to a vast audience at the same time and same instant thus making it an invaluable tool.  It’s also a great tool to organise any kind of feedback to customers regarding their views on the company itself to the services that it offers and other aspects of the company. If NHS is taken into consideration here, then the team at NHS have a tool at their disposal to answer any queries that a patient might post on twitter when that particular patient did not get the right answers from elsewhere.
#
# The NHS team can use twitter to send information regarding campaigns such as Mental Health, recent COVID related messages and information, Dementia and many other types of ailments about which not many people know about or have scant information. Individual NHS trusts can also leverage the power of twitter by sending information about any new developments in the trust such as new treatments being offered or a new appointment booking system. NHS can use the facility of Direct Messages that twitter offers to communicate with the patient about any problems they are facing and are unable to let their General Practitioners know. Or they can answer grievances any use of NHS might have who has chosen to air their views publicly. This can help stop the negative opinion developing.
#
# Tweets in my opinion add value to NHS services. Most of the times NHS relies on sending information through post or text messages or emails. These can be hit-or-miss and other than text messages which are for specific individual only, the other mediums are incapable of addressing the larger audience together and effectively. Tweets come in handy as they reach the intended audience immediately and are also cost effective. Reading a few words is easy for people rather than reading a couple of pages full of information that has come through the door. Direct Messgaes facility offered by twitter can be used by NHS for after-care services and follow ups. NHS has finally woken upto the advantage of using twitter to communicate directly with patients, provide links to websites which offer information about any doseases and control.
#
# for further information on how NHS uses twitter now can be had from this link below:
#
# https://www.theguardian.com/healthcare-network/2011/feb/16/nhs-twitter-use-tweets-communication-healthcare#:~:text=%22Twitter%20is%20an%20additional%20way,not%20get%20in%20touch%20directly.

# %% [markdown]
# # Assignment Week 6

# %% [markdown]
# ### Preparation of Workstation

# %% [markdown]
# Preparation of Workstation was done by importing all the relevant libraries and reading the relevant CSV file which is "appointments_regional"

# %%
ar.head(5)
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %% [markdown]
# ##### Maximum Dates

# %%
ar1 = ar['appointment_month'].max()
print('The Maximum Date is:', ar1 )
# Out:
# The Maximum Date is: 2022-06

# %%
ar1 = ar['appointment_month'].min()
print('The minimum Date is:', ar1 )
# Out:
# The minimum Date is: 2020-01

# %% [markdown]
# ##### Filter the data set to only look at the data from 2021-08 onwards.

# %%
ar1 = ar[ar['appointment_month'] > '2021-08']
ar1.head(5)
# Out:
#      icb_ons_code appointment_month appointment_status hcp_type  \
# 3850    E54000034           2021-09           Attended       GP
# 3851    E54000034           2021-09           Attended       GP
# 3852    E54000034           2021-09           Attended       GP
# 3853    E54000034           2021-09           Attended       GP
# 3854    E54000034           2021-09           Attended       GP
#
#      appointment_mode time_between_book_and_appointment  count_of_appointments
# 3850     Face-to-Face                             1 Day                   8288
# 3851     Face-to-Face                    15  to 21 Days                   3827
# 3852     Face-to-Face                       2 to 7 Days                  13466
# 3853     Face-to-Face                    22  to 28 Days                   1300
# 3854     Face-to-Face                     8  to 14 Days                   6825

# %% [markdown]
# ### Q1 Should the NHS start looking at increasing staff levels?

# %% [markdown]
# ##### Q1 - 1] Create a new data set:

# %%
ar_agg = ar1.groupby(['appointment_month', 'hcp_type', 'appointment_status', 'appointment_mode', \
                     'time_between_book_and_appointment']).sum().reset_index()
ar_agg.head()
# Out:
#   appointment_month hcp_type appointment_status appointment_mode  \
# 0           2021-09       GP           Attended     Face-to-Face
# 1           2021-09       GP           Attended     Face-to-Face
# 2           2021-09       GP           Attended     Face-to-Face
# 3           2021-09       GP           Attended     Face-to-Face
# 4           2021-09       GP           Attended     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                 672515
# 1                    15  to 21 Days                 277425
# 2                       2 to 7 Days                1222198
# 3                    22  to 28 Days                 158988
# 4                     8  to 14 Days                 538724

# %% [markdown]
# #### Q1 - 2] Determine average utilisation of services:

# %%
ar_df = ar_agg.groupby(['appointment_month', 'count_of_appointments']).sum().reset_index()
ar_df.head()
# Out:
#   appointment_month  count_of_appointments  \
# 0           2021-09                      1
# 1           2021-09                      2
# 2           2021-09                      4
# 3           2021-09                      5
# 4           2021-09                      6
#
#                                     hcp_type             appointment_status  \
# 0        UnknownUnknownUnknownUnknownUnknown  AttendedAttendedDNADNAUnknown
# 1  Other Practice staffUnknownUnknownUnknown   UnknownUnknownUnknownUnknown
# 2                                         GP                        Unknown
# 3                                         GP                        Unknown
# 4                             UnknownUnknown                    AttendedDNA
#
#                                         appointment_mode  \
# 0  Video/OnlineVideo/OnlineHome VisitUnknownVideo/Online
# 1            UnknownVideo/OnlineVideo/OnlineVideo/Online
# 2                                           Video/Online
# ...

# %%
ar_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3414 entries, 0 to 3413
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   appointment_month                  3414 non-null   object
#  1   hcp_type                           3414 non-null   object
#  2   appointment_status                 3414 non-null   object
#  3   appointment_mode                   3414 non-null   object
#  4   time_between_book_and_appointment  3414 non-null   object
#  5   count_of_appointments              3414 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 160.2+ KB

# %%
ar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3178 entries, 0 to 3177
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   appointment_month                  3178 non-null   object
#  1   count_of_appointments              3178 non-null   int64
#  2   hcp_type                           3178 non-null   object
#  3   appointment_status                 3178 non-null   object
#  4   appointment_mode                   3178 non-null   object
#  5   time_between_book_and_appointment  3178 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 149.1+ KB

# %%
ar_df.columns
# Out:
# Index(['appointment_month', 'count_of_appointments', 'hcp_type',
#        'appointment_status', 'appointment_mode',
#        'time_between_book_and_appointment'],
#       dtype='object')

# %%
ar_agg['appointment_month'] = ar_agg['appointment_month'].convert_dtypes()
ar_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3414 entries, 0 to 3413
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   appointment_month                  3414 non-null   string
#  1   hcp_type                           3414 non-null   object
#  2   appointment_status                 3414 non-null   object
#  3   appointment_mode                   3414 non-null   object
#  4   time_between_book_and_appointment  3414 non-null   object
#  5   count_of_appointments              3414 non-null   int64
# dtypes: int64(1), object(4), string(1)
# memory usage: 160.2+ KB

# %%
ar_df['appointment_month'] = ar_df['appointment_month'].convert_dtypes()
ar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3178 entries, 0 to 3177
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   appointment_month                  3178 non-null   string
#  1   count_of_appointments              3178 non-null   int64
#  2   hcp_type                           3178 non-null   object
#  3   appointment_status                 3178 non-null   object
#  4   appointment_mode                   3178 non-null   object
#  5   time_between_book_and_appointment  3178 non-null   object
# dtypes: int64(1), object(4), string(1)
# memory usage: 149.1+ KB

# %%
ar_df['utilisation'] = ar_df['appointment_month'].count() / 30
ar_df.head()
# Out:
#   appointment_month  count_of_appointments  \
# 0           2021-09                      1
# 1           2021-09                      2
# 2           2021-09                      4
# 3           2021-09                      5
# 4           2021-09                      6
#
#                                     hcp_type             appointment_status  \
# 0        UnknownUnknownUnknownUnknownUnknown  AttendedAttendedDNADNAUnknown
# 1  Other Practice staffUnknownUnknownUnknown   UnknownUnknownUnknownUnknown
# 2                                         GP                        Unknown
# 3                                         GP                        Unknown
# 4                             UnknownUnknown                    AttendedDNA
#
#                                         appointment_mode  \
# 0  Video/OnlineVideo/OnlineHome VisitUnknownVideo/Online
# 1            UnknownVideo/OnlineVideo/OnlineVideo/Online
# 2                                           Video/Online
# ...

# %%
ar_plot = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='time_between_book_and_appointment', estimator=sum, data=ar_agg)
ar_plot.set(xlabel='Appointment Month', ylabel='Number of Appointments', title='Number of Monthly Visits')
# Out:
# [Text(0.5, 0, 'Appointment Month'),
#  Text(0, 0.5, 'Number of Appointments'),
#  Text(0.5, 1.0, 'Number of Monthly Visits')]

# %%
ar_plot1 = sns.lineplot(x='appointment_month', y='utilisation', estimator=sum, data=ar_df)
ar_plot1.set(xlabel='Appointment Month', ylabel='Utilisation of Resources', title='Monthly Capacity Utilisation')
# Out:
# [Text(0.5, 0, 'Appointment Month'),
#  Text(0, 0.5, 'Utilisation of Resources'),
#  Text(0.5, 1.0, 'Monthly Capacity Utilisation')]

# %% [markdown]
# ### Q2 How do the healthcare professional types differ over time?

# %%
ar_hc = ar_agg.groupby(['appointment_month', 'hcp_type']).sum().reset_index()
ar_hc.head()
# Out:
#   appointment_month              hcp_type  count_of_appointments
# 0           2021-09                    GP               14487785
# 1           2021-09  Other Practice staff               13126731
# 2           2021-09               Unknown                 907985
# 3           2021-10                    GP               14300751
# 4           2021-10  Other Practice staff               14942504

# %%
ar_hc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   appointment_month      30 non-null     string
#  1   hcp_type               30 non-null     object
#  2   count_of_appointments  30 non-null     int64
# dtypes: int64(1), object(1), string(1)
# memory usage: 848.0+ bytes

# %%
ar_plot2 = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='hcp_type', estimator=sum, data=ar_hc)
ar_plot2.set(xlabel='Appointment Month', ylabel='Number of Appointments', title='Types of Healthcare Professionals')
fontsize=20
plt.legend(loc='center', frameon=True, fontsize=fontsize)

# %% [markdown]
# ### Q3 Types of attendance

# %%
ar_hc1 = ar_agg.groupby(['appointment_month', 'appointment_status']).sum().reset_index()
ar_hc1.head()
# Out:
#   appointment_month appointment_status  count_of_appointments
# 0           2021-09           Attended               25757066
# 1           2021-09                DNA                1321348
# 2           2021-09            Unknown                1444087
# 3           2021-10           Attended               27170506
# 4           2021-10                DNA                1565624

# %%
ar_hc1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   appointment_month      30 non-null     string
#  1   appointment_status     30 non-null     object
#  2   count_of_appointments  30 non-null     int64
# dtypes: int64(1), object(1), string(1)
# memory usage: 848.0+ bytes

# %%
ar_plot3 = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='appointment_status', estimator=sum, data=ar_hc1)
ar_plot3.set(xlabel='Appointment Month', ylabel='Number of Appointments', title='Types of Attendance')
fontsize=20
plt.legend(loc='center', frameon=True, fontsize=fontsize)

# %% [markdown]
# ### Q4 changes in terms of appointment type and the busiest months

# %%
ar_hc2 = ar_agg.groupby(['appointment_month', 'appointment_mode']).sum().reset_index()
ar_hc2.head()
# Out:
#   appointment_month appointment_mode  count_of_appointments
# 0           2021-09     Face-to-Face               17266602
# 1           2021-09       Home Visit                 171829
# 2           2021-09        Telephone               10068770
# 3           2021-09          Unknown                 859946
# 4           2021-09     Video/Online                 155354

# %%
ar_hc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   appointment_month      50 non-null     string
#  1   appointment_mode       50 non-null     object
#  2   count_of_appointments  50 non-null     int64
# dtypes: int64(1), object(1), string(1)
# memory usage: 1.3+ KB

# %%
ar_plot4 = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='appointment_mode', estimator=sum, data=ar_hc2)
ar_plot4.set(xlabel='Appointment Month', ylabel='Number of Appointments', title='Types of Attendance')
fontsize=15
plt.legend(loc='best', frameon=True, fontsize=fontsize)

# %% [markdown]
# ### Q5 Understand the imapct of time difference in booking and attending the appointment

# %%
ar_hc3 = ar_agg.groupby(['appointment_month', 'time_between_book_and_appointment']).sum().reset_index()
ar_hc3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   appointment_month                  80 non-null     string
#  1   time_between_book_and_appointment  80 non-null     object
#  2   count_of_appointments              80 non-null     int64
# dtypes: int64(1), object(1), string(1)
# memory usage: 2.0+ KB

# %%
ar_hc3.head(3)
# Out:
#   appointment_month time_between_book_and_appointment  count_of_appointments
# 0           2021-09                             1 Day                2666072
# 1           2021-09                    15  to 21 Days                1869263
# 2           2021-09                       2 to 7 Days                5955074

# %%
ar_plot5 = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='time_between_book_and_appointment', estimator=sum, data=ar_hc3)
ar_plot5.set(xlabel='Appointment Month', ylabel='Number of Appointments', title='Types of Attendance')
fontsize=15
plt.legend(loc='best', frameon=True, fontsize=fontsize)

# %% [markdown]
# ### Q6 How do the various service settings compare?

# %%
nc_apt = nc.groupby(['service_setting', 'count_of_appointments']).sum().reset_index()
nc_apt.head(1)
# Out:
#              service_setting  count_of_appointments  \
# 0  Extended Access Provision                      1
#
#                                                                                                                                                                                           appointment_date  \
# 0  2021-08-022021-08-132021-08-312021-09-032021-09-172021-09-302021-10-012021-10-052021-10-062021-10-122021-10-152021-10-192021-11-042021-11-092021-11-112021-11-122021-11-172021-11-182021-12-022021-1...
#
#                                                                                                                                                                                               icb_ons_code  \
# 0  E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E54000050E540000...
#
# ...

# %%
nc_apt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14019 entries, 0 to 14018
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   service_setting        14019 non-null  object
#  1   count_of_appointments  14019 non-null  int64
#  2   appointment_date       14019 non-null  object
#  3   icb_ons_code           14019 non-null  object
#  4   sub_icb_location_name  14019 non-null  object
#  5   context_type           14019 non-null  object
#  6   national_category      14019 non-null  object
#  7   appointment_month      14019 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 876.3+ KB

# %%
nc_apt['service_setting'] = nc_apt['service_setting'].convert_dtypes()
nc_apt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14019 entries, 0 to 14018
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   service_setting        14019 non-null  string
#  1   count_of_appointments  14019 non-null  int64
#  2   appointment_date       14019 non-null  object
#  3   icb_ons_code           14019 non-null  object
#  4   sub_icb_location_name  14019 non-null  object
#  5   context_type           14019 non-null  object
#  6   national_category      14019 non-null  object
#  7   appointment_month      14019 non-null  object
# dtypes: int64(1), object(6), string(1)
# memory usage: 876.3+ KB

# %% [markdown]
# ### Q6A] a plot with "General Practice" included in the service setting

# %%
nc_plot = sns.barplot(x='service_setting', y='count_of_appointments', estimator=sum, data=nc_apt)
nc_plot.set(xlabel='Types OF Services', ylabel='Number Of Appointments', title='The Number of Appointments per Service Type')
# Out:
# [Text(0.5, 0, 'Types OF Services'),
#  Text(0, 0.5, 'Number Of Appointments'),
#  Text(0.5, 1.0, 'The Number of Appointments per Service Type')]

# %% [markdown]
# ### Q6B] a plot without "General Practice" in service setting

# %%
nc_nogp = nc_apt[nc_apt['service_setting'] != 'General Practice']

# %%
nc_nogp.head()
# Out:
#              service_setting  count_of_appointments  \
# 0  Extended Access Provision                      1
# 1  Extended Access Provision                      2
# 2  Extended Access Provision                      3
# 3  Extended Access Provision                      4
# 4  Extended Access Provision                      5
#
#                                                                                                                                                                                           appointment_date  \
# 0  2021-08-022021-08-132021-08-312021-09-032021-09-172021-09-302021-10-012021-10-052021-10-062021-10-122021-10-152021-10-192021-11-042021-11-092021-11-112021-11-122021-11-172021-11-182021-12-022021-1...
# 1  2021-08-102021-08-172021-08-202021-08-262021-09-022021-09-032021-09-072021-09-142021-09-212021-09-282021-09-302021-10-052021-10-192021-10-202021-10-222021-10-262021-10-292021-11-032021-11-082021-1...
# ...

# %%
nc_nogp1 = sns.barplot(x='service_setting', y='count_of_appointments', data=nc_nogp)
nc_nogp1.set(xlabel='Types OF Services', ylabel='Number Of Appointments', title='The Number of Appointments per Service Type')
# Out:
# [Text(0.5, 0, 'Types OF Services'),
#  Text(0, 0.5, 'Number Of Appointments'),
#  Text(0.5, 1.0, 'The Number of Appointments per Service Type')]
